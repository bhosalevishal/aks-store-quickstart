# %% [markdown]
# <a href="https://colab.research.google.com/github/bhosalevishal/aks-store-quickstart/blob/main/notebooks/train-yolov8-object-detection-on-custom-dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Fri Oct 18 06:20:18 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   59C    P8              11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %%
# Pip install method (recommended)

# !pip install ultralytics==8.2.103 -q

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 29.0/112.6 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ## CLI Basics

# %% [markdown]
# ## Inference with Pre-trained COCO Model

# %% [markdown]
# ### 💻 CLI

# %%
# !mkdir -p {HOME}/datasets
# %cd {HOME}/datasets

# !pip install roboflow

from roboflow import Roboflow

rf = Roboflow(api_key="Ode7qcGA5tHMVJqIvJhu")
project = rf.workspace("nikhil-pa0mz").project("finetune-yvdgk-7hb0y")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# /content/datasets
# Collecting roboflow
#   Downloading roboflow-1.1.48-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2024.8.30)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.1)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (10.4.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.8.2)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.16.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.2.3)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.66.5)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Collecting requests-toolbelt (from roboflow)
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl.metadata (14 kB)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.54.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.1.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.4.0)
# Downloading roboflow-1.1.48-py3-none-any.whl (80 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.3/80.3 kB 5.5 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 5.4 MB/s eta 0:00:00
# Installing collected packages: filetype, python-dotenv, idna, requests-toolbelt, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 requests-toolbelt-1.0.0 roboflow-1.1.48
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in Finetune-2 to yolov8:: 100%|██████████| 86749/86749 [00:02<00:00, 43346.03it/s]
# Extracting Dataset Version Zip to Finetune-2 in yolov8:: 100%|██████████| 1594/1594 [00:00<00:00, 4131.09it/s]

# %%
import yaml

with open(f"{dataset.location}/data.yaml", 'r') as f:
    dataset_yaml = yaml.safe_load(f)
dataset_yaml["train"] = "../train/images"
dataset_yaml["val"] = "../valid/images"
dataset_yaml["test"] = "../test/images"
with open(f"{dataset.location}/data.yaml", 'w') as f:
    yaml.dump(dataset_yaml, f)

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=25 imgsz=800 plots=True
# Out:
# /content
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8s.pt to 'yolov8s.pt'...
# 100% 21.5M/21.5M [00:00<00:00, 98.6MB/s]
# New https://pypi.org/project/ultralytics/8.3.15 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=yolov8s.pt, data=/content/datasets/Finetune-2/data.yaml, epochs=25, time=None, patience=100, batch=16, imgsz=800, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100% 755k/755k [00:00<00:00, 18.3MB/s]
# Overriding model.yaml nc=80 with nc=6
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       928  ultralytics.nn.modules.conv.Conv             [3, 32, 3, 2]
#   1                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   2                  -1  1     29056  ultralytics.nn.modules.block.C2f             [64, 64, 1, True]
#   3                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   4                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   5                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   6                  -1  2    788480  ultralytics.nn.modules.block.C2f             [256, 256, 2, True]
#   7                  -1  1   1180672  ultralytics.nn.modules.conv.Conv             [256, 512, 3, 2]
#   8                  -1  1   1838080  ultralytics.nn.modules.block.C2f             [512, 512, 1, True]
#   9                  -1  1    656896  ultralytics.nn.modules.block.SPPF            [512, 512, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    591360  ultralytics.nn.modules.block.C2f             [768, 256, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  16                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  19                  -1  1    590336  ultralytics.nn.modules.conv.Conv             [256, 256, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1   1969152  ultralytics.nn.modules.block.C2f             [768, 512, 1]
#  22        [15, 18, 21]  1   2118370  ultralytics.nn.modules.head.Detect           [6, [128, 256, 512]]
# Model summary: 225 layers, 11,137,922 parameters, 11,137,906 gradients, 28.7 GFLOPs
#
# Transferred 349/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.2.0/yolov8n.pt to 'yolov8n.pt'...
# 100% 6.25M/6.25M [00:00<00:00, 135MB/s]
# AMP: checks passed ✅
# train: Scanning /content/datasets/Finetune-2/train/labels... 764 images, 159 backgrounds, 0 corrupt: 100% 764/764 [00:00<00:00, 1739.47it/s]
# train: New cache created: /content/datasets/Finetune-2/train/labels.cache
# /usr/local/lib/python3.10/dist-packages/albumentations/__init__.py:13: UserWarning: A new version of Albumentations is available: 1.4.18 (you have 1.4.15). Upgrade using: pip install -U albumentations. To disable automatic update checks, set the environment variable NO_ALBUMENTATIONS_UPDATE to 1.
#   check_for_updates()
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /content/datasets/Finetune-2/valid/labels... 16 images, 1 backgrounds, 0 corrupt: 100% 16/16 [00:00<00:00, 1428.18it/s]
# val: New cache created: /content/datasets/Finetune-2/valid/labels.cache
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001, momentum=0.9) with parameter groups 57 weight(decay=0.0), 64 weight(decay=0.0005), 63 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 800 train, 800 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 25 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/25      5.92G     0.9538      3.144     0.9772         97        800: 100% 48/48 [00:28<00:00,  1.67it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.89s/it]
#                    all         16         44      0.937      0.765      0.842      0.705
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/25      5.86G      0.796     0.7687     0.9214         70        800: 100% 48/48 [00:25<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.28it/s]
#                    all         16         44      0.921      0.975      0.992      0.828
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/25      5.85G      0.779     0.6457     0.9349        117        800: 100% 48/48 [00:23<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.62it/s]
#                    all         16         44      0.659      0.869      0.823      0.694
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/25      5.81G     0.7156     0.5548     0.9247         91        800: 100% 48/48 [00:26<00:00,  1.81it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.40it/s]
#                    all         16         44      0.916      0.887       0.99      0.862
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/25      6.12G     0.7008     0.5089     0.9162         55        800: 100% 48/48 [00:26<00:00,  1.79it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.51it/s]
#                    all         16         44      0.837      0.943      0.825      0.697
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/25      6.05G     0.6717     0.4897     0.9088         73        800: 100% 48/48 [00:23<00:00,  2.02it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.40it/s]
#                    all         16         44      0.879      0.887      0.944      0.829
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/25      6.15G     0.6577       0.46     0.9059        115        800: 100% 48/48 [00:25<00:00,  1.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.94it/s]
#                    all         16         44       0.86      0.966      0.966      0.865
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/25      5.85G       0.61     0.4278     0.8861         47        800: 100% 48/48 [00:23<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.24it/s]
#                    all         16         44      0.845      0.926      0.938      0.841
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/25      5.91G     0.5956      0.419     0.8887         59        800: 100% 48/48 [00:26<00:00,  1.84it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.44it/s]
#                    all         16         44      0.825      0.949      0.868      0.791
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/25      5.86G     0.5786     0.4179     0.8842         89        800: 100% 48/48 [00:23<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.87it/s]
#                    all         16         44       0.86      0.969      0.882      0.787
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/25      6.04G     0.5858     0.3943     0.8878         65        800: 100% 48/48 [00:26<00:00,  1.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.70it/s]
#                    all         16         44       0.86       0.97      0.972      0.873
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/25      6.05G     0.5688     0.3782     0.8744         94        800: 100% 48/48 [00:23<00:00,  2.03it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.64it/s]
#                    all         16         44      0.881      0.961      0.987      0.907
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/25      5.91G     0.5507     0.3701     0.8738         77        800: 100% 48/48 [00:25<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  6.14it/s]
#                    all         16         44      0.854       0.97      0.972      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/25      5.85G     0.5381      0.378     0.8686         66        800: 100% 48/48 [00:23<00:00,  2.00it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.40it/s]
#                    all         16         44      0.859      0.966      0.972      0.881
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/25      5.86G     0.5243     0.3503      0.867         85        800: 100% 48/48 [00:24<00:00,  1.97it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.05it/s]
#                    all         16         44      0.893      0.963      0.981      0.888
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/25      6.07G     0.5157     0.3566     0.8716         36        800: 100% 48/48 [00:27<00:00,  1.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.40it/s]
#                    all         16         44      0.909       0.97      0.969      0.897
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/25      5.83G     0.4997     0.3401     0.8673         35        800: 100% 48/48 [00:23<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.29it/s]
#                    all         16         44      0.859       0.97       0.96      0.878
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/25      6.08G     0.4886     0.3324     0.8612         40        800: 100% 48/48 [00:27<00:00,  1.73it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.46it/s]
#                    all         16         44      0.912      0.953      0.947      0.871
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/25      5.83G     0.4637     0.3235     0.8584         36        800: 100% 48/48 [00:22<00:00,  2.09it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.94it/s]
#                    all         16         44      0.897      0.931      0.959      0.895
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       20/25      5.83G     0.4465     0.3104     0.8462         44        800: 100% 48/48 [00:24<00:00,  1.93it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.83it/s]
#                    all         16         44      0.916      0.914      0.947      0.891
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       21/25      6.08G     0.4398     0.3034     0.8472         51        800: 100% 48/48 [00:23<00:00,  2.04it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.39it/s]
#                    all         16         44       0.86       0.97      0.975      0.925
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       22/25      6.07G     0.4332     0.2931     0.8462         36        800: 100% 48/48 [00:25<00:00,  1.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  2.71it/s]
#                    all         16         44      0.864      0.967      0.946      0.898
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       23/25      5.83G     0.4249     0.2816     0.8471         38        800: 100% 48/48 [00:23<00:00,  2.06it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  4.03it/s]
#                    all         16         44      0.905      0.951      0.972       0.91
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       24/25      5.83G     0.4114     0.2766     0.8429         41        800: 100% 48/48 [00:26<00:00,  1.83it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  3.02it/s]
#                    all         16         44      0.872      0.957      0.971      0.923
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       25/25      5.83G     0.3995     0.2664      0.839         49        800: 100% 48/48 [00:23<00:00,  2.01it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  5.15it/s]
#                    all         16         44      0.891      0.959      0.972      0.928
#
# 25 epochs completed in 0.187 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 22.5MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 22.5MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:00<00:00,  6.89it/s]
#                    all         16         44      0.891      0.959      0.972      0.928
#                  BlueD          3          3      0.747          1      0.913      0.836
#                  BlueO          4          9          1       0.84      0.947      0.914
#                   RedD          6          6      0.992          1      0.995      0.929
#                   RedO          6         11          1      0.984      0.995      0.946
#                 WhiteD          1          1      0.614          1      0.995      0.995
#                 WhiteO          7         14      0.994      0.929       0.99      0.946
# Speed: 0.2ms preprocess, 3.8ms inference, 0.0ms loss, 0.9ms postprocess per image
# Results saved to runs/detect/train
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    P_curve.png       train_batch2.jpg
# confusion_matrix_normalized.png			    PR_curve.png      train_batch720.jpg
# confusion_matrix.png				    R_curve.png       train_batch721.jpg
# events.out.tfevents.1729232660.7ca966c7b25d.1388.0  results.csv       train_batch722.jpg
# F1_curve.png					    results.png       val_batch0_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg  val_batch0_pred.jpg
# labels.jpg					    train_batch1.jpg  weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,906 parameters, 0 gradients, 28.4 GFLOPs
# val: Scanning /content/datasets/Finetune-2/valid/labels.cache... 16 images, 1 backgrounds, 0 corrupt: 100% 16/16 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 1/1 [00:01<00:00,  1.08s/it]
#                    all         16         44      0.891      0.959      0.972      0.929
#                  BlueD          3          3      0.747          1      0.913      0.836
#                  BlueO          4          9          1       0.84      0.947      0.914
#                   RedD          6          6      0.992          1      0.995      0.929
#                   RedO          6         11          1      0.984      0.995      0.946
#                 WhiteD          1          1      0.613          1      0.995      0.995
#                 WhiteO          7         14      0.994      0.929       0.99      0.954
# Speed: 0.3ms preprocess, 10.2ms inference, 0.0ms loss, 45.4ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11,127,132 parameters, 0 gradients, 28.4 GFLOPs
#
# image 1/25 /content/datasets/football-players-obj-detection-1/test/images/08fd33_3_6_png.rf.ee274df498bb5faaecda5ccdb1eea3eb.jpg: 480x800 20 players, 2 referees, 64.1ms
# image 2/25 /content/datasets/football-players-obj-detection-1/test/images/08fd33_9_3_png.rf.7812b9f81de027d61208dfe8ac8ecf79.jpg: 480x800 20 players, 1 referee, 15.7ms
# image 3/25 /content/datasets/football-players-obj-detection-1/test/images/40cd38_7_6_png.rf.01d51b4e36e3d5a043ff80abe3ff534d.jpg: 480x800 1 ball, 20 players, 1 referee, 15.6ms
# image 4/25 /content/datasets/football-players-obj-detection-1/test/images/42ba34_1_5_png.rf.df12ca58bef708d102b3cbbf146e077f.jpg: 480x800 1 ball, 1 goalkeeper, 22 players, 2 referees, 15.6ms
# image 5/25 /content/datasets/football-players-obj-detection-1/test/images/42ba34_5_5_png.rf.ef1514c270caf5d3f868ec1721389c98.jpg: 480x800 1 goalkeeper, 19 players, 1 referee, 15.6ms
# image 6/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_1_4_png.rf.603848772be57e4ecaefd32a926a5dd1.jpg: 480x800 1 goalkeeper, 20 players, 4 referees, 15.5ms
# image 7/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg: 480x800 20 players, 3 referees, 15.6ms
# image 8/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_1_8_png.rf.f01dd9ef4538869dd40f95ab106ff2ac.jpg: 480x800 1 goalkeeper, 21 players, 2 referees, 15.5ms
# image 9/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_3_6_png.rf.e776df3dc3436b1cd252cb9892da083a.jpg: 480x800 1 goalkeeper, 22 players, 2 referees, 15.5ms
# image 10/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_3_9_png.rf.26fd0dc802e143501b91eddef365a94d.jpg: 480x800 19 players, 3 referees, 15.5ms
# image 11/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_5_1_png.rf.9c06a9847dc2d87f01fbbf8e9eae934a.jpg: 480x800 1 goalkeeper, 20 players, 3 referees, 15.6ms
# image 12/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_9_3_png.rf.e1bfc9d168709b8dec607947cf9dc764.jpg: 480x800 1 goalkeeper, 20 players, 3 referees, 15.6ms
# image 13/25 /content/datasets/football-players-obj-detection-1/test/images/4b770a_9_4_png.rf.cf4b20007d7c40ea85117e1420a80a89.jpg: 480x800 1 goalkeeper, 24 players, 3 referees, 15.6ms
# image 14/25 /content/datasets/football-players-obj-detection-1/test/images/538438_3_6_png.rf.0320de23e94bc3382dbe0d9668f480f9.jpg: 480x800 1 goalkeeper, 18 players, 3 referees, 15.6ms
# image 15/25 /content/datasets/football-players-obj-detection-1/test/images/538438_5_2_png.rf.6ccc4ca0781178c16305fb3df75593f8.jpg: 480x800 1 goalkeeper, 20 players, 1 referee, 15.6ms
# image 16/25 /content/datasets/football-players-obj-detection-1/test/images/573e61_1_9_png.rf.d6c47eee3caf02347ff4cfe6b768cede.jpg: 480x800 19 players, 2 referees, 15.5ms
# image 17/25 /content/datasets/football-players-obj-detection-1/test/images/573e61_9_6_png.rf.3d8e07a7a906558d6a200ccdc8f34117.jpg: 480x800 1 goalkeeper, 20 players, 4 referees, 15.6ms
# image 18/25 /content/datasets/football-players-obj-detection-1/test/images/744b27_1_10_png.rf.9f1e5265556627894ad361729d1dfd0a.jpg: 480x800 1 goalkeeper, 21 players, 2 referees, 15.6ms
# image 19/25 /content/datasets/football-players-obj-detection-1/test/images/744b27_7_4_png.rf.73f5e19273b1ee6dc352961fd69653c5.jpg: 480x800 1 goalkeeper, 21 players, 3 referees, 15.5ms
# image 20/25 /content/datasets/football-players-obj-detection-1/test/images/744b27_9_9_png.rf.e2701591e6e0b2a49b9e14b9380b65f3.jpg: 480x800 1 goalkeeper, 17 players, 1 referee, 15.9ms
# image 21/25 /content/datasets/football-players-obj-detection-1/test/images/798b45_3_10_png.rf.b89253e99e2a21f3016e5351d9266aa1.jpg: 480x800 20 players, 2 referees, 15.6ms
# image 22/25 /content/datasets/football-players-obj-detection-1/test/images/798b45_3_3_png.rf.e7a81385d88082816969d797f435ab26.jpg: 480x800 1 goalkeeper, 19 players, 2 referees, 15.5ms
# image 23/25 /content/datasets/football-players-obj-detection-1/test/images/798b45_7_8_png.rf.dd67998d1274b8fac9b36c8d25c70738.jpg: 480x800 1 ball, 21 players, 2 referees, 15.5ms
# image 24/25 /content/datasets/football-players-obj-detection-1/test/images/a9f16c_2_10_png.rf.b97e3091c3ecba1447788439d0158734.jpg: 480x800 1 goalkeeper, 18 players, 3 referees, 15.6ms
# image 25/25 /content/datasets/football-players-obj-detection-1/test/images/a9f16c_2_9_png.rf.38801bf3714c41389af4ca3a28a01e42.jpg: 480x800 1 goalkeeper, 21 players, 3 referees, 15.6ms
# Speed: 3.3ms preprocess, 17.5ms inference, 38.4ms postprocess per image at shape (1, 3, 480, 800)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
import glob
from IPython.display import Image, display

# Define the base path where the folders are located
base_path = '/content/runs/detect/'

# List all directories that start with 'predict' in the base path
subfolders = [os.path.join(base_path, d) for d in os.listdir(base_path)
              if os.path.isdir(os.path.join(base_path, d)) and d.startswith('predict')]

# Find the latest folder by modification time
latest_folder = max(subfolders, key=os.path.getmtime)

image_paths = glob.glob(f'{latest_folder}/*.jpg')[:3]

# Display each image
for image_path in image_paths:
    display(Image(filename=image_path, width=600))
    print("\n")

# %% [markdown]
# ## Deploy model on Roboflow
#
# Once you have finished training your YOLOv8 model, you’ll have a set of trained weights ready for use. These weights will be in the `/runs/detect/train/weights/best.pt` folder of your project. You can upload your model weights to Roboflow Deploy to use your trained weights on our infinitely scalable infrastructure.
#
# The `.deploy()` function in the [Roboflow pip package](https://docs.roboflow.com/python) now supports uploading YOLOv8 weights.
#
# To upload model weights, add the following code to the “Inference with Custom Model” section in the aforementioned notebook:

# %%
project.version(dataset.version).deploy(model_type="yolov8", model_path=f"{HOME}/runs/detect/train/")
# Out:
# Dependency ultralytics==8.0.196 is required but found version=8.2.103, to fix: `pip install ultralytics==8.0.196`
# Would you like to continue with the wrong version of ultralytics? y/n: y
# View the status of your deployment at: https://app.roboflow.com/model-examples/football-players-obj-detection/1
# Share your model with the world at: https://universe.roboflow.com/model-examples/football-players-obj-detection/model/1

# %% [markdown]
# Follow the links above to check if the upload succeeded. It may take a couple of minutes until the model is visible to the `roboflow` SDK.

# %%
# Run inference on your model on a persistent, auto-scaling, cloud API

# Load model
model = project.version(dataset.version).model
assert model, "Model deployment is still loading"

# Choose a random test image
import os, random
test_set_loc = dataset.location + "/test/images/"
random_test_image = random.choice(os.listdir(test_set_loc))
print("running inference on " + random_test_image)

pred = model.predict(test_set_loc + random_test_image, confidence=40, overlap=30).json()
pred
# Out:
# running inference on 4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg
# {'predictions': [{'x': 615.5,
#    'y': 527.5,
#    'width': 43.0,
#    'height': 73.0,
#    'confidence': 0.91313636302948,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '415fc69e-f636-4933-993a-22c134a9fc8b',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 787.5,
#    'y': 542.5,
#    'width': 47.0,
#    'height': 75.0,
#    'confidence': 0.8991411328315735,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '3b61dc44-a7d0-42f1-8f7f-b94160591151',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 986.0,
#    'y': 372.0,
#    'width': 30.0,
#    'height': 54.0,
#    'confidence': 0.8836498260498047,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'fd5f559e-2d05-41a9-95ad-fa4284b57d88',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1007.5,
#    'y': 534.0,
#    'width': 27.0,
#    'height': 66.0,
#    'confidence': 0.8813291192054749,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'e4efaefb-d352-4ea3-a3e0-7f275cc0bff7',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1634.0,
#    'y': 808.0,
#    'width': 44.0,
#    'height': 100.0,
#    'confidence': 0.8785521984100342,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'a62241e8-c9e5-4de0-bd98-28a4bf0b7adf',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 873.5,
#    'y': 378.0,
#    'width': 35.0,
#    'height': 42.0,
#    'confidence': 0.8782786726951599,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'db836d9b-9ec2-4ace-9bbd-46d48a269446',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1426.5,
#    'y': 507.5,
#    'width': 27.0,
#    'height': 75.0,
#    'confidence': 0.8715489506721497,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '79fded27-d87e-4bd3-9214-361eceb21884',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 546.0,
#    'y': 386.0,
#    'width': 26.0,
#    'height': 58.0,
#    'confidence': 0.8680216073989868,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '8a04db92-9045-4144-9fe7-578882ac51a9',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 814.5,
#    'y': 317.5,
#    'width': 19.0,
#    'height': 41.0,
#    'confidence': 0.8626922965049744,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'b888d569-9360-4f76-acac-dd81068bbab7',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 217.0,
#    'y': 597.0,
#    'width': 26.0,
#    'height': 86.0,
#    'confidence': 0.8587268590927124,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'ba1ecf5a-2be9-4ebd-9c18-dab2614f8134',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1588.5,
#    'y': 670.0,
#    'width': 33.0,
#    'height': 94.0,
#    'confidence': 0.8573673963546753,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '523f15e5-afb2-41df-9277-503b6ac6f6e1',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1208.0,
#    'y': 322.0,
#    'width': 20.0,
#    'height': 44.0,
#    'confidence': 0.856252133846283,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'f17f4a93-5a63-4b11-a2d4-2009aafcac27',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1158.5,
#    'y': 439.5,
#    'width': 27.0,
#    'height': 65.0,
#    'confidence': 0.8495324850082397,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '7a18d877-07c6-4f5c-aaa0-8d4936e60ad7',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1044.5,
#    'y': 604.0,
#    'width': 33.0,
#    'height': 88.0,
#    'confidence': 0.8479394912719727,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'efd89768-4939-49c8-afc5-02a652ce8f98',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1321.5,
#    'y': 414.0,
#    'width': 33.0,
#    'height': 60.0,
#    'confidence': 0.846329391002655,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': 'e4b7ffa4-c09a-4a80-960b-0061a3e3a961',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 992.0,
#    'y': 743.5,
#    'width': 40.0,
#    'height': 101.0,
#    'confidence': 0.8386054039001465,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '6b5b6b45-cc8e-453a-b106-a97b71123a4a',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1391.5,
#    'y': 420.0,
#    'width': 19.0,
#    'height': 66.0,
#    'confidence': 0.819346010684967,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '891297c7-0c55-42da-b53b-31a2281f886e',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1226.0,
#    'y': 492.0,
#    'width': 20.0,
#    'height': 78.0,
#    'confidence': 0.8092968463897705,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '31114254-fd02-4fc2-b75c-3995fce78575',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1051.5,
#    'y': 426.0,
#    'width': 21.0,
#    'height': 62.0,
#    'confidence': 0.7943785190582275,
#    'class': 'referee',
#    'class_id': 3,
#    'detection_id': '778a085c-a267-496d-81bc-adc2da0f6c0a',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1252.0,
#    'y': 352.0,
#    'width': 16.0,
#    'height': 48.0,
#    'confidence': 0.784501850605011,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '1056b901-2ce2-48b6-92f7-b19776e7b3fc',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 550.5,
#    'y': 292.0,
#    'width': 21.0,
#    'height': 26.0,
#    'confidence': 0.7827689051628113,
#    'class': 'referee',
#    'class_id': 3,
#    'detection_id': '46989494-1dd6-4181-8690-18488559c229',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1869.0,
#    'y': 835.5,
#    'width': 54.0,
#    'height': 113.0,
#    'confidence': 0.7486265897750854,
#    'class': 'referee',
#    'class_id': 3,
#    'detection_id': '15ee36ca-5b6f-4b4d-a9e3-6715157bc560',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'},
#   {'x': 1052.5,
#    'y': 427.0,
#    'width': 21.0,
#    'height': 60.0,
#    'confidence': 0.4914838373661041,
#    'class': 'player',
#    'class_id': 2,
#    'detection_id': '3ec16c28-c4c7-48b8-b246-c1a870fa2475',
#    'image_path': '/content/datasets/football-players-obj-detection-1/test/images/4b770a_1_6_png.rf.281247d153a7e327e7d47a2fb548b47d.jpg',
#    'prediction_type': 'ObjectDetectionModel'}],
#  'image': {'width': '1920', 'height': '1080'}}

# %% [markdown]
# # Deploy Your Model to the Edge
#
# In addition to using the Roboflow hosted API for deployment, you can use [Roboflow Inference](https://inference.roboflow.com), an open source inference solution that has powered millions of API calls in production environments. Inference works with CPU and GPU, giving you immediate access to a range of devices, from the NVIDIA Jetson to TRT-compatible devices to ARM CPU devices.
#
# With Roboflow Inference, you can self-host and deploy your model on-device. You can deploy applications using the [Inference Docker containers](https://inference.roboflow.com/quickstart/docker/) or the pip package.
#
# For example, to install Inference on a device with an NVIDIA GPU, we can use:
#
# ```
# docker pull roboflow/roboflow-inference-server-gpu
# ```
#
# Then we can run inference via HTTP:
#
# ```python
# import requests
#
# workspace_id = ""
# model_id = ""
# image_url = ""
# confidence = 0.75
# api_key = ""
#
# infer_payload = {
#     "image": {
#         "type": "url",
#         "value": image_url,
#     },
#     "confidence": confidence,
#     "iou_threshold": iou_thresh,
#     "api_key": api_key,
# }
# res = requests.post(
#     f"http://localhost:9001/{workspace_id}/{model_id}",
#     json=infer_object_detection_payload,
# )
#
# predictions = res.json()
# ```
#
# Above, set your Roboflow workspace ID, model ID, and API key.
#
# - [Find your workspace and model ID](https://docs.roboflow.com/api-reference/workspace-and-project-ids?ref=blog.roboflow.com)
# - [Find your API key](https://docs.roboflow.com/api-reference/authentication?ref=blog.roboflow.com#retrieve-an-api-key)
#
# Also, set the URL of an image on which you want to run inference. This can be a local file.
#
# _To use your YOLOv5 model commercially with Inference, you will need a Roboflow Enterprise license, through which you gain a pass-through license for using YOLOv5. An enterprise license also grants you access to features like advanced device management, multi-model containers, auto-batch inference, and more._

# %% [markdown]
# ## 🏆 Congratulations
#
# ### Learning Resources
#
# Roboflow has produced many resources that you may find interesting as you advance your knowledge of computer vision:
#
# - [Roboflow Notebooks](https://github.com/roboflow/notebooks): A repository of over 20 notebooks that walk through how to train custom models with a range of model types, from YOLOv7 to SegFormer.
# - [Roboflow YouTube](https://www.youtube.com/c/Roboflow): Our library of videos featuring deep dives into the latest in computer vision, detailed tutorials that accompany our notebooks, and more.
# - [Roboflow Discuss](https://discuss.roboflow.com/): Have a question about how to do something on Roboflow? Ask your question on our discussion forum.
# - [Roboflow Models](https://roboflow.com): Learn about state-of-the-art models and their performance. Find links and tutorials to guide your learning.
#
# ### Convert data formats
#
# Roboflow provides free utilities to convert data between dozens of popular computer vision formats. Check out [Roboflow Formats](https://roboflow.com/formats) to find tutorials on how to convert data between formats in a few clicks.
#
# ### Connect computer vision to your project logic
#
# [Roboflow Templates](https://roboflow.com/templates) is a public gallery of code snippets that you can use to connect computer vision to your project logic. Code snippets range from sending emails after inference to measuring object distance between detections.
